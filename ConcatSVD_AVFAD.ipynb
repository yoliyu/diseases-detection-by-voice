# %%
import pandas as pd

## A_N
df1 = pd.read_csv('./datasets/AVFAD/AVFAD_a_n-all-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_a_n-all-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("a_n-all-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_a_n-F-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_a_n-F-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("a_n-F-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_a_n-M-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_a_n-M-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("a_n-M-0-120.csv")

## I_N
df1 = pd.read_csv('./datasets/AVFAD/AVFAD_i_n-all-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_i_n-all-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("i_n-all-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_i_n-F-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_i_n-F-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("i_n-F-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_i_n-M-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_i_n-M-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("i_n-M-0-120.csv")

## U_N
df1 = pd.read_csv('./datasets/AVFAD/AVFAD_u_n-all-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_u_n-all-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("u_n-all-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_u_n-F-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_u_n-F-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("u_n-F-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_u_n-M-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_u_n-M-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("u_n-M-0-120.csv")

## phrase
df1 = pd.read_csv('./datasets/AVFAD/AVFAD_phrase-all-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_phrase-all-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("phrase-all-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_phrase-F-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_phrase-F-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("phrase-F-0-120.csv")

df1 = pd.read_csv('./datasets/AVFAD/AVFAD_phrase-M-0-120.csv')
df2 = pd.read_csv('./datasets/SVD/SVD_phrase-M-0-120.csv')
frames = [df1, df2]

result1 = pd.concat(frames)
result1.to_csv("phrase-M-0-120.csv")
